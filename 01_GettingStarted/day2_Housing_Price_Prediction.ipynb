# %% [markdown]
# ## Predicting Housing Prices
#
# This exercise steps through a simple machine learning workflow, using data that is already prepared.
#
# ### Workflow
# Recall the simplest model workflow, where we perform a minimal subset of the tasks to get a model running:
#
# Stages: Tasks
# - Data Management: Analyzing Data
# - Feature Management: Feature Visualization / Inspection, Feature Selection
# - Model Management: Model Training (Evaluation)
# - Result Management: Result Evaluation
#
# Depending on how well the initial model performs, the stages can be repeated and more tasks may be added.
#
# Handy references:
# - https://www.kaggle.com/dansbecker/how-models-work
# - http://scikit-learn.org/stable/index.html

# %% [markdown]
# ### Data Management
#
# See: https://www.kaggle.com/dansbecker/starting-your-ml-project

# %%
import pandas as pd
print('pandas version: ' + pd.__version__)

# Download and inspect the training data set
# Note: data has been uploaded to github for easy access from any Jupyter notebook environment
training_set = pd.read_csv('https://github.com/lisaong/data/raw/mldds03/mldds/day2_workshop_train.csv')
print(training_set.describe())
# Out:
# pandas version: 0.22.0
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# ...

# %% [markdown]
# ### Feature Management
#
# See: https://www.kaggle.com/dansbecker/selecting-and-filtering-in-pandas

# %%
# Select a single column

# %%
# Select multiple columns

# %%
# Print a list of the columns

# %%
# From the list of columns, find a name of the column with the sales prices of the homes. 
# (Use the dot notation to extract this to a variable)

# %%
# Use the head command to print out the top few lines of the variable you just created.

# %%
# Pick any two variables and store them to a new DataFrame (as you saw above to create two_columns_of_data.)

# %%
# Use the describe command with the DataFrame you just created to see summaries of those variables.

# %% [markdown]
# ### Model Management
#
# https://www.kaggle.com/dansbecker/your-first-scikit-learn-model

# %%
# Select the target variable

# %%
# Select the predictors

# %%
# Create the model

# %%
# Train (i.e. fit) the model to the training data

# %%
# Evaluate the model (i.e. make predictions)

# %% [markdown]
# ### Result Management
#
# https://www.kaggle.com/dansbecker/model-validation

# %%
# Split training data into two: training set and validation set

# %%
# Train (i.e. fit) the model to the training set

# %%
# Evaluate the model (i.e. make predictions) using the validation set

# %%
# Compute error using the validation set

# %% [markdown]
# ### Result Management: Overfitting vs. Underfitting
#
# https://www.kaggle.com/dansbecker/underfitting-overfitting-and-model-optimization

# %%
# Trying different configurations

# %%
# Trying other models
# https://www.kaggle.com/dansbecker/random-forests
