# %% [markdown]
# Goal: exploring feature reduction on a Face Recognition Dataset
#
# Face classification dataset: http://vis-www.cs.umass.edu/lfw/
#
# - Images of well-known people
# - http://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_lfw_people.html

# %%
# From anaconda: install pillow
from sklearn.datasets import fetch_lfw_people

lfw = fetch_lfw_people(min_faces_per_person=70, resize=0.4)
# Out:
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976012
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976009
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976006
# Downloading LFW data (~200MB): https://ndownloader.figshare.com/files/5976015
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# ...
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/datasets/lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)

# %%
n_samples, height, width = lfw.images.shape
print('number of images', n_samples)
print('height (pixels)', height)
print('width (pixels)', width)
# Out:
# number of images 1288
# height (pixels) 50
# width (pixels) 37

# %%
print('labels', lfw.target_names)

print('y', lfw.target.shape, lfw.target)

print('X', lfw.data.shape, lfw.data)
# Out:
# labels ['Ariel Sharon' 'Colin Powell' 'Donald Rumsfeld' 'George W Bush'
#  'Gerhard Schroeder' 'Hugo Chavez' 'Tony Blair']
# y (1288,) [5 6 3 ... 5 3 5]
# X (1288, 1850) [[254.       254.       251.66667  ...  87.333336  88.666664  86.666664]
#  [ 39.666668  50.333332  47.       ... 117.666664 115.       133.66667 ]
#  [ 89.333336 104.       126.       ... 175.33333  183.33333  183.      ]
#  ...
#  [ 86.        80.333336  74.666664 ...  44.        49.666668  44.666668]
#  [ 50.333332  65.666664  88.       ... 197.       179.33333  166.33333 ]
#  [ 30.        27.        32.666668 ...  35.        35.333332  61.      ]]

# %%
# %matplotlib inline
# plot images to see dataset

import matplotlib.pyplot as plt
num = 5

images = lfw.data[:5] # first 5 images (X)
targets = lfw.target[:5] # first 5 targets (y)

fig, axes = plt.subplots(nrows=1, ncols=num) # 5 side-by-side
axes = axes.flatten() # from (1, 5) to (5,) vector

# for i in range(num):
#   axes[i].imshow(images[i])
#

for image, target, ax in zip(images, targets, axes):
    ax.imshow(image.reshape(height, width), cmap=plt.cm.gray) 
    # reshape: 1850 -> 50, 37
    # cmap: maps to gray colour map (no green face)
    ax.set_title(lfw.target_names[target], size=8)

plt.show()

# %%
# PCA to map X to Z for training

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

X = lfw.data
y = lfw.target

# split train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# fit using training set
pca = PCA(n_components=150)
pca.fit(X_train) # compute eigenvectors / eigenvalues

eigenfaces = pca.components_
eigenfaces
# transform train and test
# Out:
# array([[-0.00685215, -0.00752702, -0.00918911, ..., -0.0143378 ,
#         -0.01294183, -0.01188286],
#        [ 0.02304098,  0.02155215,  0.02275392, ..., -0.04400187,
#         -0.04318582, -0.04226124],
#        [ 0.02187859,  0.02016285,  0.01900916, ...,  0.05723422,
#          0.0508073 ,  0.04725171],
#        ...,
#        [-0.03465694, -0.00894184,  0.03144833, ..., -0.04308397,
#         -0.05216229, -0.01662199],
#        [-0.00238821,  0.00897194, -0.00036413, ..., -0.02575009,
#          0.005658  ,  0.05028777],
#        [-0.02443583,  0.00312744,  0.03669177, ..., -0.03624537,
#         -0.02444322,  0.00645702]], dtype=float32)

# %%
eigenfaces.shape
# Out:
# (150, 1850)

# %%
# plot the faces (eigenvectors)
eigenfaces = pca.components_

num = 5

# note: last 5, do eigenfaces[-num:]
images = eigenfaces[:num] # first 5 eigenvectors

fig, axes = plt.subplots(nrows=1, ncols=num) # 5 side-by-side
axes = axes.flatten() # from (1, 5) to (5,) vector

for image, ax in zip(images, axes):
    ax.imshow(image.reshape(height, width), cmap=plt.cm.gray) 
    # reshape: 1850 -> 50, 37
    # cmap: maps to gray colour map (no green face)

plt.show()

# %%
print(pca.explained_variance_)
# Out:
# [501418.62   391794.3    183593.     154257.23   133670.66    74828.51
#   65169.59    56409.074   52337.805   49298.832   43599.16    40965.59
#   31706.838   28196.889   27588.215   25390.396   23128.97    22155.639
#   21659.762   18729.107   18053.51    16946.477   16575.904   14548.0625
#   13765.099   13481.168   13152.365   12549.607   11496.802   10829.202
#   10203.931    9893.533    9228.298    9102.328    8670.93     8551.054
#    8154.3945   7677.2847   7519.6626   7379.3696   7257.076    6934.4395
#    6736.0405   6697.1636   6244.08     6194.194    6101.1255   5768.9556
#    5637.31     5612.9033   5418.4688   5324.1763   5194.466    5116.05
#    5023.6387   4892.3286   4669.668    4636.6147   4530.918    4485.162
#    4293.1846   4223.2295   4079.6948   3976.5366   3886.7524   3816.7085
#    3730.3696   3677.2634   3620.645    3580.468    3473.1199   3451.434
#    3338.51     3255.1409   3220.2146   3158.4421   3134.6956   3066.21
#    2982.9329   2946.266    2919.0054   2893.0002   2835.356    2777.8447
#    2738.6528   2704.8018   2653.5981   2635.6482   2585.9949   2497.7922
#    2442.2837   2384.1526   2367.0483   2311.4602   2258.3267   2235.5637
#    2185.055    2175.4062   2146.2036   2081.0337   2041.1656   2025.8667
#    1961.6182   1951.5999   1938.3547   1904.117    1897.4365   1857.1853
#    1828.2894   1806.4615   1732.2643   1724.5421   1696.7485   1661.3531
#    1647.8326   1625.3113   1603.1478   1582.4536   1557.6255   1536.1268
#    1513.42     1493.4341   1458.8958   1451.1119   1427.8812   1420.2467
#    1381.7239   1367.1428   1343.4188   1324.9469   1319.3307   1301.6702
#    1267.8423   1240.7393   1233.7654   1220.1062   1204.8579   1183.343
#    1162.5292   1150.6855   1130.1603   1124.599    1094.8414   1085.1831
#    1073.3812   1058.7853   1046.9149   1039.8025   1027.4102    993.9737]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.19346534 0.15116833 0.07083678 0.05951799 0.05157495 0.02887153
#  0.02514477 0.02176465 0.02019381 0.01902126 0.01682212 0.015806
#  0.01223364 0.01087937 0.01064453 0.00979653 0.00892399 0.00854844
#  0.00835712 0.00722636 0.00696569 0.00653856 0.00639558 0.00561317
#  0.00531107 0.00520152 0.00507466 0.00484209 0.00443588 0.0041783
#  0.00393704 0.00381728 0.00356061 0.00351201 0.00334556 0.0032993
#  0.00314626 0.00296217 0.00290136 0.00284723 0.00280004 0.00267556
#  0.00259901 0.00258401 0.00240919 0.00238994 0.00235403 0.00222587
#  0.00217508 0.00216566 0.00209064 0.00205426 0.00200421 0.00197396
#  0.0019383  0.00188764 0.00180173 0.00178897 0.00174819 0.00173054
#  0.00165646 0.00162947 0.00157409 0.00153429 0.00149965 0.00147262
#  0.00143931 0.00141882 0.00139698 0.00138147 0.00134005 0.00133169
#  0.00128812 0.00125595 0.00124247 0.00121864 0.00120948 0.00118305
#  0.00115092 0.00113678 0.00112626 0.00111622 0.00109398 0.00107179
#  0.00105667 0.00104361 0.00102385 0.00101693 0.00099777 0.00096374
#  0.00094232 0.00091989 0.00091329 0.00089184 0.00087134 0.00086256
#  0.00084307 0.00083935 0.00082808 0.00080294 0.00078756 0.00078165
#  0.00075686 0.000753   0.00074789 0.00073468 0.0007321  0.00071657
#  0.00070542 0.000697   0.00066837 0.00066539 0.00065467 0.00064101
#  0.00063579 0.0006271  0.00061855 0.00061057 0.00060099 0.00059269
#  0.00058393 0.00057622 0.00056289 0.00055989 0.00055093 0.00054798
#  0.00053312 0.00052749 0.00051834 0.00051121 0.00050905 0.00050223
#  0.00048918 0.00047872 0.00047603 0.00047076 0.00046488 0.00045658
#  0.00044855 0.00044398 0.00043606 0.00043391 0.00042243 0.0004187
#  0.00041415 0.00040852 0.00040394 0.00040119 0.00039641 0.00038351]

# %%
# eigenvalues-equivalent (explained_variance)
# print(pca.explained_variance_)

import numpy as np
# 95.7% of the variance is captured by projecting from 1850 to 150 features 
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.95672417

# %%
components = range(50, 300, 50)
evrs = []

for n in components:
    pca_temp = PCA(n_components=n)
    pca_temp.fit(X_train) # notice that PCA is unsupervised

    # compute sum of ratios (e.g. 0.95, etc)
    evr = np.sum(pca_temp.explained_variance_ratio_)
    evrs.append(evr)
    print(n, ':', evr)
    
fig, ax = plt.subplots()
ax.plot(components, evrs, marker='o')
ax.set(xlabel='n_components', ylabel='sum(explained variance ratio)')
plt.show()
# Out:
# 50 : 0.8630174
# 100 : 0.9283449
# 150 : 0.95672065
# 200 : 0.97221065
# 250 : 0.98150265

# %%
# plot the transformed "images"
Z_train = pca.transform(X_train) # Z_train = e . X_train'
Z_test = pca.transform(X_test)

print('Train set after PCA', Z_train.shape)
print('Test set after PCA', Z_test.shape)
# Out:
# Train set after PCA (966, 150)
# Test set after PCA (322, 150)

# %%
nrows=2
ncols=5

num = nrows * ncols
z_height = 15 # arbitrary (just for plotting)
z_width = 10

images = Z_train[:num] # first 5 transformed

fig, axes = plt.subplots(nrows=nrows, ncols=ncols) # 5 side-by-side
axes = axes.flatten() # from (1, 5) to (5,) vector

for image, ax in zip(images, axes):
    ax.imshow(image.reshape(z_height, z_width), cmap=plt.cm.gray) 
plt.show()

# %%
# Visualize data using feature reduction techniques e.g. PCA, t-SNE
#
# 1. Reduce to 2d or 3d
# 2. Plot
# 3. Analyze the plot visually

pca_plot = PCA(n_components=2) # Z will have 2 components

Z_train_2d = pca_plot.fit_transform(Z_train)

print('Before', Z_train.shape)
print('After', Z_train_2d.shape)

# plot
fig, ax = plt.subplots(figsize=(10, 8))

for i in range(len(lfw.target_names)):
    indices = (y_train == i) # all rows with label = i

    # scatter plot rows with label = i
    ax.scatter(Z_train_2d[indices, 0], Z_train_2d[indices, 1],
              label=lfw.target_names[i])

ax.legend()
plt.show()
# Out:
# Before (966, 150)
# After (966, 2)

# %%
# Visualize data using feature reduction techniques e.g. PCA, t-SNE
#
# 1. Reduce to 2d or 3d
# 2. Plot
# 3. Analyze the plot visually

from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)

Z_train_2d = tsne.fit_transform(Z_train)

print('Before', Z_train.shape)
print('After', Z_train_2d.shape)
# Out:
# Before (966, 150)
# After (966, 2)

# %%
# %matplotlib inline
# plot
fig, ax = plt.subplots(figsize=(8, 6))

# to compare any classes, just select the labels
#for i in range(len(lfw.target_names)):
for i in [1, 3]:
    indices = (y_train == i) # all rows with label = i

    # scatter plot rows with label = i
    ax.scatter(Z_train_2d[indices, 0], Z_train_2d[indices, 1],
              label=lfw.target_names[i])

ax.legend()
plt.show()

# %%
# Visualize data using feature reduction techniques e.g. PCA, t-SNE
#
# 1. Reduce to 2d or 3d
# 2. Plot
# 3. Analyze the plot visually

from sklearn.manifold import TSNE

from mpl_toolkits.mplot3d import Axes3D # <-- import 3D

tsne = TSNE(n_components=3, random_state=42) # <-- 3 components

Z_train_2d = tsne.fit_transform(Z_train)

print('Before', Z_train.shape)
print('After', Z_train_2d.shape)
# Out:
# Before (966, 150)
# After (966, 3)

# %%
# %matplotlib notebook

# plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

for i in range(len(lfw.target_names)):
    indices = (y_train == i) # all rows with label = i

    # scatter plot rows with label = i
    ax.scatter(Z_train_2d[indices, 0], Z_train_2d[indices, 1],
               Z_train_2d[indices, 2], # <-- 3rd axis
              label=lfw.target_names[i])

ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# Training

# 1. SGD + Logistic Regression
# 2. SVM with some non-linear kernel
# 3. Compare evaluation metrics

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(verbose=True, random_state=42)
sgd_clf.fit(Z_train, y_train)

# using test set like validation set
scores = sgd_clf.score(Z_test, y_test)
print(scores) # accuracy
# Out:
# -- Epoch 1
# Norm: 53861.09, NNZs: 150, Bias: -3015.091656, T: 966, Avg. loss: 3598278.233198
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 39068.17, NNZs: 150, Bias: -4649.217562, T: 1932, Avg. loss: 2177170.285856
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 34449.60, NNZs: 150, Bias: -5933.016418, T: 2898, Avg. loss: 1659654.398487
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 28813.55, NNZs: 150, Bias: -6840.094359, T: 3864, Avg. loss: 1185958.909926
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 25304.46, NNZs: 150, Bias: -7669.449542, T: 4830, Avg. loss: 1099596.834368
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 58514.73, NNZs: 150, Bias: -2132.097380, T: 966, Avg. loss: 2688953.462559
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 54178.32, NNZs: 150, Bias: -3298.117652, T: 1932, Avg. loss: 1388590.844755
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 47361.83, NNZs: 150, Bias: -4131.434209, T: 2898, Avg. loss: 1120507.717832
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 41206.24, NNZs: 150, Bias: -4723.119442, T: 3864, Avg. loss: 771040.654773
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 36332.65, NNZs: 150, Bias: -5229.631873, T: 4830, Avg. loss: 656496.146568
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 55932.49, NNZs: 150, Bias: -2786.111829, T: 966, Avg. loss: 3628349.033648
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 43043.79, NNZs: 150, Bias: -4389.897836, T: 1932, Avg. loss: 2136457.054453
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 38620.75, NNZs: 150, Bias: -5554.321482, T: 2898, Avg. loss: 1559716.643461
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 32766.53, NNZs: 150, Bias: -6372.836419, T: 3864, Avg. loss: 1153384.336713
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 28531.96, NNZs: 150, Bias: -7136.046011, T: 4830, Avg. loss: 1011760.951616
# Total training time: 0.01 seconds.
# -- Epoch 1
# Norm: 69938.85, NNZs: 150, Bias: -735.513445, T: 966, Avg. loss: 1860273.634379
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 59743.25, NNZs: 150, Bias: -1092.934618, T: 1932, Avg. loss: 762635.309205
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 54908.78, NNZs: 150, Bias: -1364.803911, T: 2898, Avg. loss: 486939.253675
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 46688.11, NNZs: 150, Bias: -1501.820694, T: 3864, Avg. loss: 363252.680197
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 42141.32, NNZs: 150, Bias: -1627.674890, T: 4830, Avg. loss: 306956.545145
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 51192.88, NNZs: 150, Bias: -2809.003273, T: 966, Avg. loss: 3677816.910739
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 41802.67, NNZs: 150, Bias: -4507.588458, T: 1932, Avg. loss: 2277821.133842
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 34582.41, NNZs: 150, Bias: -5722.755301, T: 2898, Avg. loss: 1623110.551554
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 29836.07, NNZs: 150, Bias: -6656.213357, T: 3864, Avg. loss: 1243174.443917
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 25207.02, NNZs: 150, Bias: -7387.706622, T: 4830, Avg. loss: 992405.095953
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 51604.96, NNZs: 150, Bias: -2989.566739, T: 966, Avg. loss: 3877157.766919
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 41388.39, NNZs: 150, Bias: -4834.638624, T: 1932, Avg. loss: 2355337.960618
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 31985.53, NNZs: 150, Bias: -6177.436837, T: 2898, Avg. loss: 1744184.267493
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 28680.44, NNZs: 150, Bias: -7107.862250, T: 3864, Avg. loss: 1184754.737188
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 23896.91, NNZs: 150, Bias: -7919.740190, T: 4830, Avg. loss: 1076917.402227
# Total training time: 0.01 seconds.
# -- Epoch 1
# Norm: 57101.54, NNZs: 150, Bias: -2643.885503, T: 966, Avg. loss: 3448201.563608
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 45820.05, NNZs: 150, Bias: -4187.378852, T: 1932, Avg. loss: 2082985.210243
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 38923.60, NNZs: 150, Bias: -5324.454750, T: 2898, Avg. loss: 1506724.227750
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 33404.49, NNZs: 150, Bias: -6145.396963, T: 3864, Avg. loss: 1111268.523734
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 30047.34, NNZs: 150, Bias: -6886.787868, T: 4830, Avg. loss: 968803.735272
# Total training time: 0.00 seconds.
# 0.6645962732919255
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s finished

# %%
from sklearn.svm import SVC

svc = SVC() # TODO: GridSearchCV is best
svc.fit(Z_train, y_train)

scores = svc.score(Z_test, y_test)
print(scores) # accuracy
# Out:
# 0.453416149068323

# %%
y_pred_svc = svc.predict(Z_test)
y_pred_sgd = sgd_clf.predict(Z_test)

print('Actual (ground truth)', y_test[:10])
print('---')
print('prediction SVC', y_pred_svc[:10])
print('prediction Logistic Regression', y_pred_sgd[:10])
# Out:
# Actual (ground truth) [3 3 6 3 3 3 4 1 3 3]
# ---
# prediction SVC [3 3 3 3 3 3 3 3 3 3]
# prediction Logistic Regression [3 1 2 3 3 3 4 1 3 2]

# %%
from sklearn.metrics import confusion_matrix

print('SVC\n', confusion_matrix(y_test, y_pred_svc))

print('Logistic Regression\n', confusion_matrix(y_test, y_pred_sgd))
# Out:
# SVC
#  [[  0   0   0  13   0   0   0]
#  [  0   0   0  60   0   0   0]
#  [  0   0   0  27   0   0   0]
#  [  0   0   0 146   0   0   0]
#  [  0   0   0  25   0   0   0]
#  [  0   0   0  15   0   0   0]
#  [  0   0   0  36   0   0   0]]
# Logistic Regression
#  [[ 7  2  2  1  0  0  1]
#  [ 3 48  3  2  0  2  2]
#  [ 1  3 18  3  1  0  1]
#  [ 4  9 14 98 11  2  8]
#  [ 0  2  0  1 15  6  1]
#  [ 1  1  0  1  2 10  0]
#  [ 1  2  5  4  5  1 18]]

# %%
# %matplotlib inline
import seaborn as sns

cm_sgd = confusion_matrix(y_test, y_pred_sgd)

fig, ax = plt.subplots()
sns.heatmap(cm_sgd, annot=True, ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
# Out:
# Text(33,0.5,'Actual')

# %%
cm_svc = confusion_matrix(y_test, y_pred_svc)

fig, ax = plt.subplots()
sns.heatmap(cm_svc, annot=True, ax=ax, fmt='d') # fmt='d' prints integers
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
plt.show()

# %%
# precision / recall
from sklearn.metrics import classification_report

# usage: classification_report(y_true, y_pred)
print(classification_report(y_test, y_pred_sgd))
print(classification_report(y_test, y_pred_svc))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.41      0.54      0.47        13
#           1       0.72      0.80      0.76        60
#           2       0.43      0.67      0.52        27
#           3       0.89      0.67      0.77       146
#           4       0.44      0.60      0.51        25
#           5       0.48      0.67      0.56        15
#           6       0.58      0.50      0.54        36
#
# avg / total       0.71      0.66      0.68       322
#
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        13
#           1       0.00      0.00      0.00        60
#           2       0.00      0.00      0.00        27
#           3       0.45      1.00      0.62       146
#           4       0.00      0.00      0.00        25
#           5       0.00      0.00      0.00        15
#           6       0.00      0.00      0.00        36
#
# avg / total       0.21      0.45      0.28       322
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Improvements:
# 1. Scale
# 3. Balance the classes
# 3. Tune algorithms. SVC and Logistic Regression

# %%
# 1. Scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Z_train_scaled = scaler.fit_transform(Z_train)
Z_test_scaled = scaler.transform(Z_test)

# %%
# fit our classifiers

sgd_clf = SGDClassifier(verbose=True, random_state=42)
sgd_clf.fit(Z_train_scaled, y_train)

scores = sgd_clf.score(Z_test_scaled, y_test)
print(scores) # accuracy

y_pred_sgd = sgd_clf.predict(Z_test_scaled)
cm_sgd = confusion_matrix(y_test, y_pred_sgd)

fig, ax = plt.subplots()
sns.heatmap(cm_sgd, annot=True, ax=ax, fmt='d')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

print(classification_report(y_test, y_pred_sgd))
# Out:
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s finished
# -- Epoch 1
# Norm: 399.59, NNZs: 150, Bias: -670.099262, T: 966, Avg. loss: 38.867472
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 383.41, NNZs: 150, Bias: -616.729536, T: 1932, Avg. loss: 5.614895
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 328.92, NNZs: 150, Bias: -601.834455, T: 2898, Avg. loss: 2.251322
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 312.38, NNZs: 150, Bias: -576.200281, T: 3864, Avg. loss: 0.854720
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 287.23, NNZs: 150, Bias: -565.645905, T: 4830, Avg. loss: 0.301412
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 558.23, NNZs: 150, Bias: -450.284050, T: 966, Avg. loss: 56.195100
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 467.86, NNZs: 150, Bias: -451.189885, T: 1932, Avg. loss: 14.086810
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 406.45, NNZs: 150, Bias: -413.993179, T: 2898, Avg. loss: 8.556040
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 386.27, NNZs: 150, Bias: -373.185518, T: 3864, Avg. loss: 5.711719
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 351.71, NNZs: 150, Bias: -357.918884, T: 4830, Avg. loss: 3.329502
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 493.73, NNZs: 150, Bias: -590.090960, T: 966, Avg. loss: 45.996063
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 420.16, NNZs: 150, Bias: -563.470389, T: 1932, Avg. loss: 10.633600
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 380.09, NNZs: 150, Bias: -530.023351, T: 2898, Avg. loss: 4.264787
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 352.35, NNZs: 150, Bias: -509.686664, T: 3864, Avg. loss: 2.761371
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 327.72, NNZs: 150, Bias: -491.244301, T: 4830, Avg. loss: 1.755075
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 652.22, NNZs: 150, Bias: -165.377866, T: 966, Avg. loss: 84.781055
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 494.96, NNZs: 150, Bias: -134.911360, T: 1932, Avg. loss: 39.780616
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 415.88, NNZs: 150, Bias: -120.601720, T: 2898, Avg. loss: 26.885285
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 360.53, NNZs: 150, Bias: -109.408822, T: 3864, Avg. loss: 22.486283
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 323.14, NNZs: 150, Bias: -71.214111, T: 4830, Avg. loss: 16.183825
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 467.11, NNZs: 150, Bias: -602.258190, T: 966, Avg. loss: 47.577743
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 415.09, NNZs: 150, Bias: -576.883800, T: 1932, Avg. loss: 14.595984
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 371.56, NNZs: 150, Bias: -562.312947, T: 2898, Avg. loss: 7.220413
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 352.01, NNZs: 150, Bias: -533.569499, T: 3864, Avg. loss: 3.908832
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 339.46, NNZs: 150, Bias: -506.221949, T: 4830, Avg. loss: 1.797892
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 400.78, NNZs: 150, Bias: -689.406731, T: 966, Avg. loss: 44.737915
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 360.14, NNZs: 150, Bias: -659.932709, T: 1932, Avg. loss: 5.929799
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 337.37, NNZs: 150, Bias: -632.053008, T: 2898, Avg. loss: 1.127242
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 297.11, NNZs: 150, Bias: -620.805645, T: 3864, Avg. loss: 0.305528
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 278.84, NNZs: 150, Bias: -607.486595, T: 4830, Avg. loss: 0.421432
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 445.48, NNZs: 150, Bias: -582.879871, T: 966, Avg. loss: 48.673301
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 401.70, NNZs: 150, Bias: -544.086653, T: 1932, Avg. loss: 18.200020
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 385.09, NNZs: 150, Bias: -484.613022, T: 2898, Avg. loss: 10.530833
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 337.43, NNZs: 150, Bias: -465.155339, T: 3864, Avg. loss: 5.582520
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 335.23, NNZs: 150, Bias: -421.710343, T: 4830, Avg. loss: 4.726527
# Total training time: 0.00 seconds.
# 0.7919254658385093
#              precision    recall  f1-score   support
#
#           0       0.55      0.46      0.50        13
#           1       0.75      0.87      0.81        60
#           2       0.69      0.67      0.68        27
#           3       0.85      0.88      0.87       146
#           4       0.62      0.64      0.63        25
#           5       0.88      0.47      0.61        15
#           6       0.87      0.75      0.81        36
#
# avg / total       0.79      0.79      0.79       322

# %%
svc = SVC()
svc.fit(Z_train_scaled, y_train)

scores = svc.score(Z_test_scaled, y_test)
print(scores) # accuracy

y_pred_svc = svc.predict(Z_test_scaled)
cm_svc = confusion_matrix(y_test, y_pred_svc)

fig, ax = plt.subplots()
sns.heatmap(cm_svc, annot=True, ax=ax, fmt='d')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

print(classification_report(y_test, y_pred_svc))
# Out:
# 0.8012422360248447
#              precision    recall  f1-score   support
#
#           0       1.00      0.38      0.56        13
#           1       0.84      0.87      0.85        60
#           2       1.00      0.48      0.65        27
#           3       0.73      0.98      0.83       146
#           4       1.00      0.68      0.81        25
#           5       1.00      0.40      0.57        15
#           6       1.00      0.61      0.76        36
#
# avg / total       0.85      0.80      0.79       322

# %%
# 2. Balance the classes

# %%
import pandas as pd
df_y = pd.DataFrame(y_train, columns=['labels'])
df_y.hist() # plot a histogram to see distribution

# count how many rows per label using value_counts()
print(df_y['labels'].value_counts())
# Out:
# 3    384
# 1    176
# 6    108
# 2     94
# 4     84
# 0     64
# 5     56
# Name: labels, dtype: int64

# %%
# first, combine all training set (y, Z_train) in 1 dataframe
# this way, the values and labels are lined up
df_train = pd.concat([df_y, pd.DataFrame(Z_train)], axis=1) # concat columns

df_train.head()
# Out:
#    labels            0           1           2           3           4  \
# 0       3 -1469.752197 -654.597534  911.345337   14.463200 -276.975128
# 1       1   935.489197  371.077759  228.872345   48.175323  432.501190
# 2       2  -539.006653  -12.350151 -102.795380  196.022308  476.894592
# 3       6   -83.137329   72.949707   -4.175087  826.382202 -201.023300
# 4       4  -280.672638  267.176880 -107.542236 -256.003906  656.289978
#
#             5           6           7           8    ...            140  \
# 0 -141.525635  218.396118  249.841263  104.718643    ...      -2.821050
# 1 -184.196945  -46.488663  252.798416  199.049637    ...       2.082787
# 2 -153.463715   17.803413  384.975128   27.225712    ...       4.280724
# 3  170.536697  226.075684  117.868271  -79.156967    ...     -38.064293
# 4  251.063034   89.127670 -330.387848  268.812988    ...     -44.851963
#
#          141        142        143        144        145        146  \
# 0 -87.940392  31.100269 -16.940128 -52.773003 -31.019585   0.182061
# 1   0.862553  14.970934  17.206593 -45.536217   7.214027  -1.276612
# 2  59.262566  -5.299802  18.897879 -12.825931  33.882633  42.853657
# 3  42.594357  -8.631041  46.294697  -3.119851   5.247797   7.343635
# 4 -19.732933  -4.070642  31.518593   6.442757  10.191830  43.735474
#
#          147        148        149
# 0  16.293438   8.933348 -39.374062
# 1  39.930222   0.550176 -26.451630
# 2  10.000498  12.500004   2.750441
# 3 -55.478184 -22.181063 -69.387375
# 4  19.064270 -14.503818 -44.072693
#
# [5 rows x 151 columns]

# %%
# next, randomly select 100 rows for labels 1 and 3
df_3 = df_train.loc[df_train['labels'] == 3].sample(n=100, random_state=42)
print(df_3['labels'].value_counts())

df_1 = df_train.loc[df_train['labels'] == 1].sample(n=100, random_state=42)
print(df_1['labels'].value_counts())

# get the remaining labels
df_others = df_train.loc[(df_train['labels'] != 3) & (df_train['labels'] != 1)]
print(df_others['labels'].value_counts())

# combine all labels into the balanced dataset
df_balanced = pd.concat([df_others, df_1, df_3])
print(df_balanced['labels'].value_counts())

# shuffle the dataset because we joined groups of the same labels together
df_balanced = df_balanced.sample(frac=1, random_state=42)
df_balanced['labels'].hist()
# Out:
# 3    100
# Name: labels, dtype: int64
# 1    100
# Name: labels, dtype: int64
# 6    108
# 2     94
# 4     84
# 0     64
# 5     56
# Name: labels, dtype: int64
# 6    108
# 3    100
# 1    100
# 2     94
# 4     84
# 0     64
# 5     56
# Name: labels, dtype: int64

# %%
# fit our classifiers

Z_train_balanced = df_balanced.loc[:, df_balanced.columns != 'labels']
y_train_balanced = df_balanced['labels']

scaler = StandardScaler()
Z_train_balanced_scaled = scaler.fit_transform(Z_train_balanced)
Z_test_scaled = scaler.transform(Z_test)

sgd_clf = SGDClassifier(verbose=True, random_state=42)
sgd_clf.fit(Z_train_balanced_scaled, y_train_balanced)

scores = sgd_clf.score(Z_test_scaled, y_test)
print(scores) # accuracy

y_pred_sgd = sgd_clf.predict(Z_test_scaled)
cm_sgd = confusion_matrix(y_test, y_pred_sgd)

fig, ax = plt.subplots()
sns.heatmap(cm_sgd, annot=True, ax=ax, fmt='d')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

print(classification_report(y_test, y_pred_sgd))
# Out:
# /anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s finished
# -- Epoch 1
# Norm: 504.61, NNZs: 150, Bias: -556.167196, T: 606, Avg. loss: 53.732888
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 433.88, NNZs: 150, Bias: -564.945392, T: 1212, Avg. loss: 15.490477
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 393.30, NNZs: 150, Bias: -560.371187, T: 1818, Avg. loss: 4.831899
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 372.74, NNZs: 150, Bias: -531.230064, T: 2424, Avg. loss: 1.681943
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 330.77, NNZs: 150, Bias: -523.200983, T: 3030, Avg. loss: 0.315867
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 548.97, NNZs: 150, Bias: -465.509145, T: 606, Avg. loss: 53.337298
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 493.84, NNZs: 150, Bias: -455.151526, T: 1212, Avg. loss: 19.727005
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 428.54, NNZs: 150, Bias: -447.440730, T: 1818, Avg. loss: 4.081446
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 400.83, NNZs: 150, Bias: -422.059216, T: 2424, Avg. loss: 1.536763
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 370.24, NNZs: 150, Bias: -408.813218, T: 3030, Avg. loss: 2.302451
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 539.91, NNZs: 150, Bias: -488.842229, T: 606, Avg. loss: 57.499607
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 475.20, NNZs: 150, Bias: -529.194234, T: 1212, Avg. loss: 20.893640
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 430.84, NNZs: 150, Bias: -504.199180, T: 1818, Avg. loss: 4.944159
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 396.46, NNZs: 150, Bias: -476.900452, T: 2424, Avg. loss: 4.025886
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 354.17, NNZs: 150, Bias: -468.516110, T: 3030, Avg. loss: 0.950229
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 578.44, NNZs: 150, Bias: -466.772388, T: 606, Avg. loss: 77.825537
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 517.50, NNZs: 150, Bias: -475.651673, T: 1212, Avg. loss: 32.419095
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 458.91, NNZs: 150, Bias: -437.743434, T: 1818, Avg. loss: 15.755593
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 432.89, NNZs: 150, Bias: -397.130421, T: 2424, Avg. loss: 9.810787
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 413.54, NNZs: 150, Bias: -372.736617, T: 3030, Avg. loss: 6.434039
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 505.11, NNZs: 150, Bias: -558.434876, T: 606, Avg. loss: 69.044599
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 474.07, NNZs: 150, Bias: -547.840952, T: 1212, Avg. loss: 24.352718
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 452.14, NNZs: 150, Bias: -520.634703, T: 1818, Avg. loss: 12.608998
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 397.85, NNZs: 150, Bias: -513.407477, T: 2424, Avg. loss: 6.058652
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 395.20, NNZs: 150, Bias: -477.800056, T: 3030, Avg. loss: 3.790520
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 500.30, NNZs: 150, Bias: -615.195089, T: 606, Avg. loss: 51.181594
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 406.87, NNZs: 150, Bias: -605.231504, T: 1212, Avg. loss: 4.621094
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 367.48, NNZs: 150, Bias: -588.105624, T: 1818, Avg. loss: 1.332952
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 342.63, NNZs: 150, Bias: -569.586384, T: 2424, Avg. loss: 0.785845
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 302.78, NNZs: 150, Bias: -566.590219, T: 3030, Avg. loss: 0.379054
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 543.39, NNZs: 150, Bias: -478.625812, T: 606, Avg. loss: 65.490705
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 480.03, NNZs: 150, Bias: -491.251008, T: 1212, Avg. loss: 30.220820
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 463.49, NNZs: 150, Bias: -431.926605, T: 1818, Avg. loss: 17.711823
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 427.32, NNZs: 150, Bias: -413.951426, T: 2424, Avg. loss: 12.373761
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 403.42, NNZs: 150, Bias: -390.528999, T: 3030, Avg. loss: 6.422438
# Total training time: 0.00 seconds.
# 0.717391304347826
#              precision    recall  f1-score   support
#
#           0       0.39      0.54      0.45        13
#           1       0.72      0.80      0.76        60
#           2       0.56      0.74      0.63        27
#           3       0.90      0.71      0.79       146
#           4       0.52      0.68      0.59        25
#           5       0.54      0.47      0.50        15
#           6       0.71      0.81      0.75        36
#
# avg / total       0.75      0.72      0.72       322

# %%
svc = SVC()
svc.fit(Z_train_balanced_scaled, y_train_balanced)

scores = svc.score(Z_test_scaled, y_test)
print(scores) # accuracy

y_pred_svc = svc.predict(Z_test_scaled)
cm_svc = confusion_matrix(y_test, y_pred_svc)

fig, ax = plt.subplots()
sns.heatmap(cm_svc, annot=True, ax=ax, fmt='d')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

print(classification_report(y_test, y_pred_svc))
# Out:
# 0.8167701863354038
#              precision    recall  f1-score   support
#
#           0       0.56      0.69      0.62        13
#           1       0.72      0.92      0.81        60
#           2       0.79      0.70      0.75        27
#           3       0.98      0.81      0.89       146
#           4       0.72      0.84      0.78        25
#           5       0.82      0.60      0.69        15
#           6       0.70      0.89      0.78        36
#
# avg / total       0.84      0.82      0.82       322

# %%
# Tune SVC hyperparameters

# http://scikit-learn.org/stable/modules/svm.html#tips-on-practical-use
# https://cs.stanford.edu/people/karpathy/svmjs/demo/
# https://medium.com/@aneesha/svm-parameter-tuning-in-scikit-learn-using-gridsearchcv-2413c02125a0
    
from sklearn.model_selection import GridSearchCV

# SVC(C=1.0, kernel='rbf', degree=3, gamma='auto'...)

# Error penalty
# smaller = more sensitive to noise
Cs = [.001, .01, .1, 1., 10.] 

# Sensitivity: RBF(x, z) = exp(−gamma * ‖x − z‖^2)
# larger = higher tendency to overfit
gammas = [.001, .01, .1, 1, 10.]

# 3-fold cross validation
gs = GridSearchCV(SVC(probability=True), param_grid={'C': Cs, 'gamma': gammas}, verbose=True)

# try the unbalanced (but scaled) dataset
gs.fit(Z_train_scaled, y_train)

print(gs.score(Z_test_scaled, y_test))
print(gs.best_params_)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  1.2min finished
# 0.8198757763975155
# {'C': 10.0, 'gamma': 0.001}

# %%
y_pred_svc = gs.predict(Z_test_scaled)
cm_svc = confusion_matrix(y_test, y_pred_svc)

fig, ax = plt.subplots()
sns.heatmap(cm_svc, annot=True, ax=ax, fmt='d')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

print(classification_report(y_test, y_pred_svc))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.50      0.62      0.55        13
#           1       0.74      0.83      0.78        60
#           2       0.71      0.74      0.73        27
#           3       0.89      0.90      0.89       146
#           4       0.86      0.72      0.78        25
#           5       0.75      0.60      0.67        15
#           6       0.93      0.78      0.85        36
#
# avg / total       0.83      0.82      0.82       322

# %%
def get_predictions(model, images):
    # PCA transform to 150 features
    Z_images = pca.transform(images)

    # scale
    Z_images_scaled = scaler.transform(Z_images)
    
    # predict
    predictions = model.predict(Z_images_scaled)    
    probs = model.predict_proba(Z_images_scaled)
    
    return predictions, probs

# %%
# Get an image to predict

test_images = X_test[-5:] # last 5 test images
test_targets = y_test[-5:]

predictions, probs = get_predictions(gs, test_images)

fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(5, 10))
axes = axes.flatten()

for i in range(len(test_targets)):
    axes[i].imshow(test_images[i].reshape(height, width), cmap=plt.cm.gray)

    actual = test_targets[i]
    prob = probs[i][predicted] # probability for the predicted label
    
    axes[i].set_title('Actual %s, Predicted %s (%.3f)' % (actual, predicted, prob), size=8)
    axes[i].axis('off')

plt.show()
