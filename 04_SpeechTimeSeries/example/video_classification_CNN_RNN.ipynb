# %% [markdown]
# <a href="https://colab.research.google.com/github/lisaong/mldds-courseware/blob/master/04_SpeechTimeSeries/example/video_classification_CNN_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Classification with RNN
#
# This notebook demonstrates video classification of action videos using a time-distributed CNN + RNN.
#
# The CNN will use the InceptionV3 model (transfer learning) to perform feature extraction.
#
# 1. Run on Colab
# 2. Runtime -> Change Runtime Type: GPU
#
# We will be using a subset of techniques demonstrated in the more complex example here: https://github.com/harvitronix/five-video-classification-methods
#
# We will also be using a small dataset to demonstrate how this works. Only 5 classes were selected from the UCF101 video classification dataset.
#
# Incidentally, this entire dataset is also part of Tensorflow (but already preprocessed): https://www.tensorflow.org/datasets/catalog/ucf101. The goal of doing this manually is to demonstrate how to go about processing your own video dataset.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# Ensure that ffmpeg is installed as we will be using it to extract frames
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import random

sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Download video data
#
# We will download the data from github and create a folder structure like this:
#
# ```
# train/
#   Archery/
#   Basketball/
#   ...
# test/
#   Archery/
#   Basketball/
#   ...
# ```

# %%
# Instead of 101 classes, we will start small, just 5 classes.

classes = [
  'Archery',
  'Basketball',
  'BasketballDunk',
  'CricketBowling',
  'CricketShot',
]

classes
# Out:
# ['Archery', 'Basketball', 'BasketballDunk', 'CricketBowling', 'CricketShot']

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9681 sha256=89025d17a408b62f5a405f00e7aa2ca6ed957bb10ac95b081d482a56ddc38a2b
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# Download subset of the dataset for the classes we have.
import wget
import zipfile
import os

def download_and_extract(label, folder):
  url = f'https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/{folder}/{label}.zip'
  print(f'Downloaded {url}')

  # prepare folders
  if not os.path.isdir(folder):
    os.mkdir(folder)
  filename = f'{label}.zip'

  # download
  wget.download(url, filename)

  # extract within folder
  with zipfile.ZipFile(filename) as f:
    f.extractall(folder)
  print(f'Extracted {os.path.join(folder, label)}')
  
  # delete zip archive
  os.remove(filename)

# %%
for label in classes:
  download_and_extract(label, 'train')
  download_and_extract(label, 'test')
# Out:
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/train/Archery.zip
# Extracted train/Archery
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/test/Archery.zip
# Extracted test/Archery
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/train/Basketball.zip
# Extracted train/Basketball
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/test/Basketball.zip
# Extracted test/Basketball
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/train/BasketballDunk.zip
# Extracted train/BasketballDunk
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/test/BasketballDunk.zip
# Extracted test/BasketballDunk
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/train/CricketBowling.zip
# Extracted train/CricketBowling
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/test/CricketBowling.zip
# Extracted test/CricketBowling
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/train/CricketShot.zip
# Extracted train/CricketShot
# Downloaded https://github.com/lisaong/mldds-courseware/raw/master/data/ucf101-5classes/test/CricketShot.zip
# Extracted test/CricketShot

# %%
# Files are downloaded, press 'Refresh' in the Files tab to see them

# %% [markdown]
# ## Extracting frames from videos
#
# In this step, we will use ffmpeg to extract frames from the video files and save the frames into images.
#
# This will also generate a csv file describing the class, video filename, and number of frames for each video.
#
# This can take a while to run.

# %%
# https://github.com/harvitronix/five-video-classification-methods/blob/master/data/2_extract_files.py
import glob
import csv
from subprocess import call

def get_nb_frames_for_video(video_parts):
    """Given video parts of an (assumed) already extracted video, return
    the number of frames that were extracted."""
    train_or_test, classname, filename_no_ext, _ = video_parts
    generated_files = glob.glob(os.path.join(train_or_test, classname,
                                filename_no_ext + '*.jpg'))
    return len(generated_files)

def get_video_path_parts(video_path):
    """Given a full path to a video, return its parts."""
    parts = video_path.split(os.path.sep)
    filename = parts[2]
    filename_no_ext = filename.split('.')[0]
    classname = parts[1]
    train_or_test = parts[0]

    return train_or_test, classname, filename_no_ext, filename

def check_already_extracted(video_parts):
    """Check to see if we created the -0001 frame of this file."""
    train_or_test, classname, filename_no_ext, _ = video_parts
    return bool(os.path.exists(os.path.join(train_or_test, classname,
                               filename_no_ext + '-0001.jpg')))

def extract_files():
    """After we have all of our videos split between train and test, and
    all nested within folders representing their classes, we need to
    make a data file that we can reference when training our RNN(s).
    
    This will let us keep track of image sequences and other parts
    of the training process.
    
    We'll first need to extract images from each of the videos. We'll
    need to record the following data in the file:
    [train|test], class, filename, nb frames
    
    Extracting can be done with ffmpeg:
    `ffmpeg -i video.mpg image-%04d.jpg`
    """

    data_file = []
    folders = ['train', 'test']
    for folder in folders:
      class_folders = glob.glob(os.path.join(folder, '*'))
      
      for vid_class in class_folders:
        class_files = glob.glob(os.path.join(vid_class, '*.avi'))
        
        for video_path in class_files:
          # Get the parts of the file path
          video_parts  = get_video_path_parts(video_path)
          train_or_test, classname, filename_no_ext, filename = video_parts          

          # Only extract if we haven't done it yet. Otherwise, just get
          # the info.
          if not check_already_extracted(video_parts):
            # Now extract it.
            src = os.path.join(train_or_test, classname, filename)
            dest = os.path.join(train_or_test, classname,
                                filename_no_ext + '-%04d.jpg')
            call(["ffmpeg", "-i", src, dest])

            # Now get how many frames it is.
            nb_frames = get_nb_frames_for_video(video_parts)

            data_file.append([train_or_test, classname, filename_no_ext, nb_frames])

            print("Generated %d frames for %s" % (nb_frames, filename_no_ext))

    with open('data_file.csv', 'w') as fout:
        writer = csv.writer(fout)
        writer.writerows(data_file)

    print("Extracted and wrote %d video files." % (len(data_file)))

# %%
# If you have many more files, recommend run directly from a Terminal
# (outside of Jupyter or Colab - because Colab can hang)
extract_files()
# Out:
# Generated 46 frames for v_CricketShot_g21_c01
# Generated 62 frames for v_CricketShot_g18_c01
# Generated 92 frames for v_CricketShot_g15_c02
# Generated 100 frames for v_CricketShot_g12_c05
# Generated 87 frames for v_CricketShot_g24_c04
# Generated 170 frames for v_CricketShot_g22_c01
# Generated 68 frames for v_CricketShot_g08_c04
# Generated 95 frames for v_CricketShot_g17_c05
# Generated 183 frames for v_CricketShot_g22_c05
# Generated 87 frames for v_CricketShot_g19_c05
# Generated 90 frames for v_CricketShot_g17_c04
# Generated 96 frames for v_CricketShot_g11_c05
# Generated 77 frames for v_CricketShot_g18_c05
# Generated 74 frames for v_CricketShot_g09_c04
# Generated 133 frames for v_CricketShot_g20_c01
# Generated 82 frames for v_CricketShot_g08_c06
# Generated 100 frames for v_CricketShot_g16_c02
# Generated 184 frames for v_CricketShot_g22_c02
# Generated 134 frames for v_CricketShot_g11_c07
# Generated 90 frames for v_CricketShot_g25_c07
# Generated 72 frames for v_CricketShot_g25_c04
# Generated 76 frames for v_CricketShot_g13_c03
# Generated 63 frames for v_CricketShot_g24_c02
# Generated 78 frames for v_CricketShot_g23_c03
# Generated 52 frames for v_CricketShot_g10_c04
# Generated 57 frames for v_CricketShot_g16_c06
# Generated 66 frames for v_CricketShot_g15_c05
# Generated 85 frames for v_CricketShot_g18_c02
# Generated 71 frames for v_CricketShot_g24_c01
# Generated 73 frames for v_CricketShot_g10_c03
# Generated 70 frames for v_CricketShot_g10_c06
# Generated 136 frames for v_CricketShot_g20_c03
# Generated 47 frames for v_CricketShot_g16_c05
# Generated 136 frames for v_CricketShot_g22_c06
# Generated 100 frames for v_CricketShot_g24_c05
# Generated 141 frames for v_CricketShot_g11_c06
# Generated 75 frames for v_CricketShot_g08_c02
# Generated 88 frames for v_CricketShot_g17_c06
# Generated 52 frames for v_CricketShot_g13_c04
# Generated 53 frames for v_CricketShot_g21_c03
# Generated 70 frames for v_CricketShot_g21_c04
# Generated 56 frames for v_CricketShot_g21_c05
# Generated 105 frames for v_CricketShot_g23_c02
# Generated 71 frames for v_CricketShot_g18_c03
# Generated 62 frames for v_CricketShot_g13_c05
# Generated 89 frames for v_CricketShot_g24_c07
# Generated 74 frames for v_CricketShot_g09_c02
# Generated 139 frames for v_CricketShot_g11_c03
# Generated 50 frames for v_CricketShot_g16_c07
# Generated 96 frames for v_CricketShot_g17_c02
# Generated 80 frames for v_CricketShot_g24_c03
# Generated 158 frames for v_CricketShot_g22_c03
# Generated 94 frames for v_CricketShot_g08_c07
# Generated 84 frames for v_CricketShot_g19_c04
# Generated 76 frames for v_CricketShot_g25_c03
# Generated 98 frames for v_CricketShot_g08_c05
# Generated 88 frames for v_CricketShot_g23_c01
# Generated 108 frames for v_CricketShot_g10_c07
# Generated 125 frames for v_CricketShot_g12_c06
# Generated 77 frames for v_CricketShot_g25_c06
# Generated 54 frames for v_CricketShot_g13_c06
# Generated 75 frames for v_CricketShot_g15_c06
# Generated 122 frames for v_CricketShot_g14_c07
# Generated 96 frames for v_CricketShot_g15_c07
# Generated 98 frames for v_CricketShot_g09_c06
# Generated 105 frames for v_CricketShot_g17_c01
# Generated 89 frames for v_CricketShot_g12_c03
# Generated 104 frames for v_CricketShot_g16_c01
# Generated 84 frames for v_CricketShot_g10_c02
# Generated 63 frames for v_CricketShot_g15_c01
# Generated 107 frames for v_CricketShot_g14_c03
# Generated 80 frames for v_CricketShot_g10_c05
# Generated 141 frames for v_CricketShot_g23_c05
# Generated 78 frames for v_CricketShot_g09_c01
# Generated 106 frames for v_CricketShot_g11_c04
# Generated 132 frames for v_CricketShot_g22_c04
# Generated 89 frames for v_CricketShot_g20_c06
# Generated 135 frames for v_CricketShot_g14_c02
# Generated 118 frames for v_CricketShot_g14_c06
# Generated 101 frames for v_CricketShot_g20_c07
# Generated 52 frames for v_CricketShot_g13_c02
# Generated 132 frames for v_CricketShot_g11_c01
# Generated 262 frames for v_CricketShot_g22_c07
# Generated 105 frames for v_CricketShot_g14_c01
# Generated 101 frames for v_CricketShot_g21_c06
# Generated 53 frames for v_CricketShot_g08_c03
# Generated 113 frames for v_CricketShot_g10_c01
# Generated 134 frames for v_CricketShot_g12_c02
# Generated 82 frames for v_CricketShot_g09_c05
# Generated 75 frames for v_CricketShot_g08_c01
# Generated 125 frames for v_CricketShot_g20_c02
# Generated 65 frames for v_CricketShot_g15_c04
# Generated 106 frames for v_CricketShot_g12_c07
# Generated 81 frames for v_CricketShot_g19_c03
# Generated 112 frames for v_CricketShot_g12_c04
# Generated 60 frames for v_CricketShot_g09_c07
# Generated 61 frames for v_CricketShot_g19_c01
# Generated 50 frames for v_CricketShot_g13_c01
# Generated 69 frames for v_CricketShot_g24_c06
# Generated 109 frames for v_CricketShot_g14_c05
# Generated 86 frames for v_CricketShot_g15_c03
# Generated 79 frames for v_CricketShot_g21_c02
# Generated 79 frames for v_CricketShot_g25_c05
# Generated 55 frames for v_CricketShot_g19_c02
# Generated 87 frames for v_CricketShot_g25_c01
# Generated 98 frames for v_CricketShot_g16_c03
# Generated 86 frames for v_CricketShot_g09_c03
# Generated 72 frames for v_CricketShot_g13_c07
# Generated 106 frames for v_CricketShot_g17_c03
# Generated 136 frames for v_CricketShot_g14_c04
# Generated 114 frames for v_CricketShot_g12_c01
# Generated 62 frames for v_CricketShot_g20_c05
# Generated 67 frames for v_CricketShot_g18_c04
# Generated 134 frames for v_CricketShot_g11_c02
# Generated 136 frames for v_CricketShot_g20_c04
# Generated 137 frames for v_CricketShot_g23_c04
# Generated 91 frames for v_CricketShot_g25_c02
# Generated 73 frames for v_CricketShot_g16_c04
# Generated 66 frames for v_BasketballDunk_g20_c01
# Generated 82 frames for v_BasketballDunk_g14_c05
# Generated 91 frames for v_BasketballDunk_g23_c01
# Generated 88 frames for v_BasketballDunk_g14_c01
# Generated 69 frames for v_BasketballDunk_g10_c04
# Generated 89 frames for v_BasketballDunk_g25_c04
# Generated 91 frames for v_BasketballDunk_g11_c05
# Generated 67 frames for v_BasketballDunk_g20_c03
# Generated 84 frames for v_BasketballDunk_g21_c01
# Generated 80 frames for v_BasketballDunk_g15_c07
# Generated 76 frames for v_BasketballDunk_g16_c06
# Generated 82 frames for v_BasketballDunk_g15_c02
# Generated 74 frames for v_BasketballDunk_g18_c05
# Generated 76 frames for v_BasketballDunk_g16_c01
# v_Archery_g04_c03-0125.jpg  v_Archery_g07_c06-0065.jpg
# v_Archery_g04_c03-0126.jpg  v_Archery_g07_c06-0066.jpg
# v_Archery_g04_c03-0127.jpg  v_Archery_g07_c06-0067.jpg
# v_Archery_g04_c03-0128.jpg  v_Archery_g07_c06-0068.jpg
# v_Archery_g04_c03-0129.jpg  v_Archery_g07_c06.avi

# %%
# Contents of the data file
# [train|test], class, filename, nb frames
# !cat data_file.csv
# Out:
# train,CricketShot,v_CricketShot_g21_c01,46
# train,CricketShot,v_CricketShot_g18_c01,62
# train,CricketShot,v_CricketShot_g15_c02,92
# train,CricketShot,v_CricketShot_g12_c05,100
# train,CricketShot,v_CricketShot_g24_c04,87
# train,CricketShot,v_CricketShot_g22_c01,170
# train,CricketShot,v_CricketShot_g08_c04,68
# train,CricketShot,v_CricketShot_g17_c05,95
# train,CricketShot,v_CricketShot_g22_c05,183
# train,CricketShot,v_CricketShot_g19_c05,87
# train,CricketShot,v_CricketShot_g17_c04,90
# train,CricketShot,v_CricketShot_g11_c05,96
# train,CricketShot,v_CricketShot_g18_c05,77
# train,CricketShot,v_CricketShot_g09_c04,74
# train,CricketShot,v_CricketShot_g20_c01,133
# train,CricketShot,v_CricketShot_g08_c06,82
# train,CricketShot,v_CricketShot_g16_c02,100
# train,CricketShot,v_CricketShot_g22_c02,184
# train,CricketShot,v_CricketShot_g11_c07,134
# train,CricketShot,v_CricketShot_g25_c07,90
# train,CricketShot,v_CricketShot_g25_c04,72
# train,CricketShot,v_CricketShot_g13_c03,76
# train,CricketShot,v_CricketShot_g24_c02,63
# train,CricketShot,v_CricketShot_g23_c03,78
# train,CricketShot,v_CricketShot_g10_c04,52
# train,CricketShot,v_CricketShot_g16_c06,57
# train,CricketShot,v_CricketShot_g15_c05,66
# train,CricketShot,v_CricketShot_g18_c02,85
# train,CricketShot,v_CricketShot_g24_c01,71
# train,CricketShot,v_CricketShot_g10_c03,73
# train,CricketShot,v_CricketShot_g10_c06,70
# train,CricketShot,v_CricketShot_g20_c03,136
# train,CricketShot,v_CricketShot_g16_c05,47
# train,CricketShot,v_CricketShot_g22_c06,136
# train,CricketShot,v_CricketShot_g24_c05,100
# train,CricketShot,v_CricketShot_g11_c06,141
# train,CricketShot,v_CricketShot_g08_c02,75
# train,CricketShot,v_CricketShot_g17_c06,88
# train,CricketShot,v_CricketShot_g13_c04,52
# train,CricketShot,v_CricketShot_g21_c03,53
# train,CricketShot,v_CricketShot_g21_c04,70
# train,CricketShot,v_CricketShot_g21_c05,56
# train,CricketShot,v_CricketShot_g23_c02,105
# train,CricketShot,v_CricketShot_g18_c03,71
# train,CricketShot,v_CricketShot_g13_c05,62
# train,CricketShot,v_CricketShot_g24_c07,89
# train,CricketShot,v_CricketShot_g09_c02,74
# train,CricketShot,v_CricketShot_g11_c03,139
# train,CricketShot,v_CricketShot_g16_c07,50
# train,CricketShot,v_CricketShot_g17_c02,96
# train,CricketShot,v_CricketShot_g24_c03,80
# train,CricketShot,v_CricketShot_g22_c03,158
# train,CricketShot,v_CricketShot_g08_c07,94
# train,CricketShot,v_CricketShot_g19_c04,84
# train,CricketShot,v_CricketShot_g25_c03,76
# train,CricketShot,v_CricketShot_g08_c05,98
# train,CricketShot,v_CricketShot_g23_c01,88
# train,CricketShot,v_CricketShot_g10_c07,108
# train,CricketShot,v_CricketShot_g12_c06,125
# train,CricketShot,v_CricketShot_g25_c06,77
# train,CricketShot,v_CricketShot_g13_c06,54
# train,CricketShot,v_CricketShot_g15_c06,75
# train,CricketShot,v_CricketShot_g14_c07,122
# train,CricketShot,v_CricketShot_g15_c07,96
# train,CricketShot,v_CricketShot_g09_c06,98
# train,CricketShot,v_CricketShot_g17_c01,105
# train,CricketShot,v_CricketShot_g12_c03,89
# train,CricketShot,v_CricketShot_g16_c01,104
# train,CricketShot,v_CricketShot_g10_c02,84
# train,CricketShot,v_CricketShot_g15_c01,63
# train,CricketShot,v_CricketShot_g14_c03,107
# train,CricketShot,v_CricketShot_g10_c05,80
# train,CricketShot,v_CricketShot_g23_c05,141
# train,CricketShot,v_CricketShot_g09_c01,78
# train,CricketShot,v_CricketShot_g11_c04,106
# train,CricketShot,v_CricketShot_g22_c04,132
# train,CricketShot,v_CricketShot_g20_c06,89
# train,CricketShot,v_CricketShot_g14_c02,135
# train,CricketShot,v_CricketShot_g14_c06,118
# train,CricketShot,v_CricketShot_g20_c07,101
# train,CricketShot,v_CricketShot_g13_c02,52
# train,CricketShot,v_CricketShot_g11_c01,132
# train,CricketShot,v_CricketShot_g22_c07,262
# train,CricketShot,v_CricketShot_g14_c01,105
# train,CricketShot,v_CricketShot_g21_c06,101
# train,CricketShot,v_CricketShot_g08_c03,53
# train,CricketShot,v_CricketShot_g10_c01,113
# train,CricketShot,v_CricketShot_g12_c02,134
# train,CricketShot,v_CricketShot_g09_c05,82
# train,CricketShot,v_CricketShot_g08_c01,75
# train,CricketShot,v_CricketShot_g20_c02,125
# train,CricketShot,v_CricketShot_g15_c04,65
# train,CricketShot,v_CricketShot_g12_c07,106
# train,CricketShot,v_CricketShot_g19_c03,81
# train,CricketShot,v_CricketShot_g12_c04,112
# train,CricketShot,v_CricketShot_g09_c07,60
# train,CricketShot,v_CricketShot_g19_c01,61
# train,CricketShot,v_CricketShot_g13_c01,50
# train,CricketShot,v_CricketShot_g24_c06,69
# train,CricketShot,v_CricketShot_g14_c05,109
# train,CricketShot,v_CricketShot_g15_c03,86
# train,CricketShot,v_CricketShot_g21_c02,79
# train,CricketShot,v_CricketShot_g25_c05,79
# train,CricketShot,v_CricketShot_g19_c02,55
# train,CricketShot,v_CricketShot_g25_c01,87
# train,CricketShot,v_CricketShot_g16_c03,98
# train,CricketShot,v_CricketShot_g09_c03,86
# train,CricketShot,v_CricketShot_g13_c07,72
# train,CricketShot,v_CricketShot_g17_c03,106
# train,CricketShot,v_CricketShot_g14_c04,136
# train,CricketShot,v_CricketShot_g12_c01,114
# train,CricketShot,v_CricketShot_g20_c05,62
# train,CricketShot,v_CricketShot_g18_c04,67
# train,CricketShot,v_CricketShot_g11_c02,134
# train,BasketballDunk,v_BasketballDunk_g09_c04,81
# train,BasketballDunk,v_BasketballDunk_g08_c01,51
# train,BasketballDunk,v_BasketballDunk_g14_c04,88
# train,BasketballDunk,v_BasketballDunk_g12_c02,56
# train,BasketballDunk,v_BasketballDunk_g13_c02,67
# train,BasketballDunk,v_BasketballDunk_g24_c01,85
# train,BasketballDunk,v_BasketballDunk_g14_c02,82
# train,BasketballDunk,v_BasketballDunk_g14_c03,87
# train,BasketballDunk,v_BasketballDunk_g11_c01,115
# train,BasketballDunk,v_BasketballDunk_g24_c04,155
# train,BasketballDunk,v_BasketballDunk_g24_c05,168
# train,BasketballDunk,v_BasketballDunk_g16_c05,74
# train,BasketballDunk,v_BasketballDunk_g16_c02,75
# train,BasketballDunk,v_BasketballDunk_g13_c04,72
# train,BasketballDunk,v_BasketballDunk_g25_c02,117
# train,BasketballDunk,v_BasketballDunk_g13_c01,47
# train,BasketballDunk,v_BasketballDunk_g09_c03,82
# train,BasketballDunk,v_BasketballDunk_g15_c03,124
# train,BasketballDunk,v_BasketballDunk_g12_c04,58
# train,BasketballDunk,v_BasketballDunk_g20_c04,78
# train,BasketballDunk,v_BasketballDunk_g17_c07,75
# train,BasketballDunk,v_BasketballDunk_g18_c04,51
# train,BasketballDunk,v_BasketballDunk_g23_c05,93
# train,BasketballDunk,v_BasketballDunk_g15_c04,102
# train,BasketballDunk,v_BasketballDunk_g08_c05,87
# train,BasketballDunk,v_BasketballDunk_g12_c03,70
# train,BasketballDunk,v_BasketballDunk_g25_c01,82
# train,BasketballDunk,v_BasketballDunk_g08_c04,59
# train,BasketballDunk,v_BasketballDunk_g19_c03,58
# train,BasketballDunk,v_BasketballDunk_g08_c02,66
# train,BasketballDunk,v_BasketballDunk_g18_c06,67
# train,BasketballDunk,v_BasketballDunk_g15_c06,102
# train,BasketballDunk,v_BasketballDunk_g20_c06,72
# train,BasketballDunk,v_BasketballDunk_g17_c06,61
# train,BasketballDunk,v_BasketballDunk_g25_c03,81
# train,BasketballDunk,v_BasketballDunk_g24_c02,105
# train,BasketballDunk,v_BasketballDunk_g12_c05,68
# train,BasketballDunk,v_BasketballDunk_g11_c02,84
# train,BasketballDunk,v_BasketballDunk_g16_c04,59
# train,BasketballDunk,v_BasketballDunk_g19_c04,53
# train,BasketballDunk,v_BasketballDunk_g20_c05,72
# train,BasketballDunk,v_BasketballDunk_g21_c03,116
# train,BasketballDunk,v_BasketballDunk_g10_c05,98
# train,BasketballDunk,v_BasketballDunk_g14_c07,98
# test,CricketShot,v_CricketShot_g06_c06,169
# test,CricketShot,v_CricketShot_g04_c05,84
# test,CricketShot,v_CricketShot_g02_c07,94
# test,CricketShot,v_CricketShot_g03_c07,103
# test,CricketShot,v_CricketShot_g07_c06,99
# test,CricketShot,v_CricketShot_g04_c07,88
# test,CricketShot,v_CricketShot_g02_c06,96
# test,CricketShot,v_CricketShot_g05_c03,77
# test,CricketShot,v_CricketShot_g04_c02,116
# test,CricketShot,v_CricketShot_g01_c02,91
# test,CricketShot,v_CricketShot_g06_c07,100
# test,CricketShot,v_CricketShot_g07_c07,102
# test,CricketShot,v_CricketShot_g03_c04,101
# test,CricketShot,v_CricketShot_g06_c02,127
# test,CricketShot,v_CricketShot_g01_c03,95
# test,CricketShot,v_CricketShot_g05_c01,56
# test,CricketShot,v_CricketShot_g02_c05,127
# test,CricketShot,v_CricketShot_g04_c03,99
# test,CricketShot,v_CricketShot_g06_c04,135
# test,CricketShot,v_CricketShot_g01_c06,76
# test,CricketShot,v_CricketShot_g04_c01,80
# test,CricketShot,v_CricketShot_g03_c03,93
# test,CricketShot,v_CricketShot_g06_c05,122
# test,CricketShot,v_CricketShot_g06_c03,118
# test,CricketShot,v_CricketShot_g07_c03,134
# test,CricketShot,v_CricketShot_g07_c02,126
# test,CricketShot,v_CricketShot_g07_c04,118
# test,CricketShot,v_CricketShot_g02_c04,94
# test,CricketShot,v_CricketShot_g02_c03,97
# test,CricketShot,v_CricketShot_g05_c06,65
# test,CricketShot,v_CricketShot_g05_c07,66
# test,CricketShot,v_CricketShot_g05_c04,57
# test,CricketShot,v_CricketShot_g01_c01,84
# test,CricketShot,v_CricketShot_g02_c02,93
# test,CricketShot,v_CricketShot_g01_c07,71
# test,CricketShot,v_CricketShot_g02_c01,105
# test,CricketShot,v_CricketShot_g06_c01,122
# test,CricketShot,v_CricketShot_g01_c04,72
# test,CricketShot,v_CricketShot_g03_c06,142
# test,CricketShot,v_CricketShot_g03_c02,104
# test,CricketShot,v_CricketShot_g01_c05,95
# test,CricketShot,v_CricketShot_g03_c05,105
# test,CricketShot,v_CricketShot_g07_c05,119
# test,CricketShot,v_CricketShot_g04_c04,75
# test,CricketShot,v_CricketShot_g05_c02,64
# test,CricketShot,v_CricketShot_g07_c01,100
# test,CricketShot,v_CricketShot_g04_c06,77
# test,CricketShot,v_CricketShot_g05_c05,56
# test,CricketShot,v_CricketShot_g03_c01,92
# test,BasketballDunk,v_BasketballDunk_g03_c06,66
# test,BasketballDunk,v_BasketballDunk_g05_c03,56
# test,BasketballDunk,v_BasketballDunk_g02_c02,109
# test,BasketballDunk,v_BasketballDunk_g03_c03,74
# test,BasketballDunk,v_BasketballDunk_g06_c03,53
# test,BasketballDunk,v_BasketballDunk_g02_c03,71
# test,BasketballDunk,v_BasketballDunk_g03_c02,76
# test,BasketballDunk,v_BasketballDunk_g04_c01,51
# test,BasketballDunk,v_BasketballDunk_g04_c02,55
# test,BasketballDunk,v_BasketballDunk_g07_c04,46
# test,BasketballDunk,v_BasketballDunk_g02_c04,58
# test,BasketballDunk,v_BasketballDunk_g01_c01,61
# test,BasketballDunk,v_BasketballDunk_g04_c04,48
# test,BasketballDunk,v_BasketballDunk_g07_c06,51
# test,BasketballDunk,v_BasketballDunk_g01_c07,57
# test,BasketballDunk,v_BasketballDunk_g02_c01,56
# test,BasketballDunk,v_BasketballDunk_g05_c06,84
# test,BasketballDunk,v_BasketballDunk_g04_c03,62
# test,BasketballDunk,v_BasketballDunk_g01_c03,71
# test,BasketballDunk,v_BasketballDunk_g06_c01,52
# test,BasketballDunk,v_BasketballDunk_g07_c05,37
# test,BasketballDunk,v_BasketballDunk_g05_c04,52
# test,BasketballDunk,v_BasketballDunk_g01_c06,80
# test,BasketballDunk,v_BasketballDunk_g05_c02,80
# test,BasketballDunk,v_BasketballDunk_g01_c02,65
# test,BasketballDunk,v_BasketballDunk_g05_c05,53
# test,BasketballDunk,v_BasketballDunk_g01_c05,66
# test,BasketballDunk,v_BasketballDunk_g03_c05,71
# test,BasketballDunk,v_BasketballDunk_g01_c04,61
# test,BasketballDunk,v_BasketballDunk_g03_c04,81
# test,BasketballDunk,v_BasketballDunk_g07_c03,53
# test,BasketballDunk,v_BasketballDunk_g05_c01,52
# test,BasketballDunk,v_BasketballDunk_g06_c04,63
# test,BasketballDunk,v_BasketballDunk_g07_c02,35
# test,BasketballDunk,v_BasketballDunk_g07_c01,42
# test,BasketballDunk,v_BasketballDunk_g06_c02,61
# test,BasketballDunk,v_BasketballDunk_g03_c01,58

# %% [markdown]
# ## Data Generators
#
# To feed the training and validation to the model, we will use generators to read files from the classes.
#
# Some pre-processing questions:
# - How do you deal with different sequence lengths? There is no helper function like "pad_sequences"
# - Since this is action classification, any value in zooming in to the person in the frame? Add people detection filter (using OpenCV?)?

# %%
# https://github.com/harvitronix/five-video-classification-methods/blob/master/processor.py

from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np

def process_image(image, target_shape):
    """Given an image, process it and return the array."""
    # Load the image.
    h, w, _ = target_shape
    image = load_img(image, target_size=(h, w))

    # Turn it into numpy, normalize and return.
    img_arr = img_to_array(image)
    x = (img_arr / 255.).astype(np.float32)

    return x

# %%
# Reference: 
# https://github.com/harvitronix/five-video-classification-methods/blob/master/data.py
def get_data_descriptions(data_file_path):
    """Load our data description."""
    with open(data_file_path, 'r') as f:
        reader = csv.reader(f)
        data_desc = list(reader)
    return sorted(data_desc)

def split_train_test(data_desc, shuffle=True, random_seed=None):
    random.seed(random_seed)

    """Split the data into train and test groups."""
    train = [item for item in data_desc if item[0] == 'train']
    test = [item for item in data_desc if item[0] == 'test']

    if shuffle:
      random.shuffle(train) # no need to shuffle test

    return train, test

def get_frames_for_sample(sample):
    """Given a sample row from the data file, get all the corresponding frame
    filenames."""
    path = os.path.join(sample[0], sample[1])
    filename = sample[2]
    # frames should be in order
    return sorted(glob.glob(os.path.join(path, f'{filename}*jpg')))

def set_fixed_length(frames, seq_length=50):
    """Given a set of frames (filenames), pad them so that they are the
    same length.
      
    There is no "standard" way for this, it's up to your creativity:

    If the sequence is too short, we will take the first image and "front fill"
    (duplicate) to the front of the sequence. 
    This way action happens towards the end of the sequence.

    If the sequence is too long, we will take the middle portion (truncate from
    front and back). The idea is that the main action should happen in the middle
    of the video. 

    Note that the reference code used a different strategy:
    it only loads samples with length >= seq_length, and then re-samples the
    frames if length > seq_length
    """
    if len(frames) < seq_length:
      frontfill_length = seq_length - len(frames)
      padded_frames = [frames[0]] * frontfill_length
      padded_frames.extend(frames)
      result = padded_frames
    elif len(frames) > seq_length:
      truncate_length = (len(frames) - seq_length)//2
      start = truncate_length
      end = truncate_length + seq_length
      result = frames[start:end]
    else:
      result = frames # no change

    assert len(result) == seq_length
    return result

def build_image_sequence(frames, image_shape=(224, 224, 3)):
    """Given a set of frames (filenames), build our sequence."""
    return [process_image(x, image_shape) for x in frames]

def get_class_one_hot(classes, class_str):
    """Given a class as a string, one-hot it for training."""
    # Encode it first.
    label_encoded = classes.index(class_str)

    # Now one-hot it.
    label_hot = tf.keras.utils.to_categorical(label_encoded, len(classes))

    assert len(label_hot) == len(classes)
    return label_hot

def get_one_hot_class(label_hot, classes):
    """Given a one-hot encoded label, return the class string."""
    return classes[label_hot.argmax()]

# %%
def plot_sequences(sequence, label, n=5):
  """Helper routine to plot first N sequences
  """
  fig, ax = plt.subplots(ncols=n, figsize=(3*n, 3))
  for i in range(n):
    ax[i].imshow(sequence[i])

  plt.suptitle(f'{label} (first {n} frames)')
  plt.show()

# %%
# Test the processing code
desc = get_data_descriptions('data_file.csv')
train_desc, test_desc = split_train_test(desc)
sample = train_desc[0]

raw_frames = get_frames_for_sample(sample)
frames = set_fixed_length(raw_frames, seq_length=50)
sequence = build_image_sequence(frames)

print(f'Length before: {len(raw_frames)}, Length after: {len(frames)}')

label = get_class_one_hot(classes, sample[1])
print(f'Class one-hot: {label}')

plot_sequences(sequence, get_one_hot_class(label, classes))
# Out:
# Length before: 72, Length after: 50
# Class one-hot: [0. 0. 1. 0. 0.]

# %%
# Combine the processing code above into a generator
# We use make a thread safe generator to support multi-processing, so
# that training can be sped up if needed
# https://anandology.com/blog/using-iterators-and-generators/
# https://github.com/harvitronix/five-video-classification-methods/blob/master/data.py

import operator
import threading

class threadsafe_iterator:
    def __init__(self, iterator):
        self.iterator = iterator
        self.lock = threading.Lock()

    def __iter__(self):
        return self

    def __next__(self):
        with self.lock:
            return next(self.iterator)

def threadsafe_generator(func):
    """Decorator"""
    def gen(*a, **kw):
        return threadsafe_iterator(func(*a, **kw))
    return gen

@threadsafe_generator
def frame_generator(data_file_path, classes, train_or_test, batch_size, seq_len):
    """Return a generator that we can use to train and validate.
    """
    desc = get_data_descriptions(data_file_path)
    train_desc, test_desc = split_train_test(desc)

    data = train_desc if train_or_test == 'train' else test_desc
    print(f'Creating {train_or_test} generator with {len(data)} samples')

    while 1:
      X, y = [], []

      # Generate batch_size samples
      for _ in range(batch_size):
          # Reset to be safe
          sequence = None

          # Get a random sample
          sample = random.choice(data)

          # Get frames
          raw_frames = get_frames_for_sample(sample)
          frames = set_fixed_length(raw_frames, seq_length=seq_len)

          # Build the image sequence
          sequence = build_image_sequence(frames)

          X.append(sequence)
          y.append(get_class_one_hot(classes, sample[1]))

          yield np.array(X), np.array(y)

# %%
# Test our generator
generator = frame_generator('data_file.csv', classes, 'train', batch_size=10,
                            seq_len=30)
X_batch, y_batch = next(generator)

print(y_batch)
print(X_batch.shape)

plot_sequences(X_batch[0], get_one_hot_class(y_batch[0], classes))
# Out:
# Creating train generator with 212 samples
# [[0. 0. 1. 0. 0.]]
# (1, 30, 224, 224, 3)
